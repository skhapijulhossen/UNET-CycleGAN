jpg
# /kaggle/input/horse2zebra/data/train/horses/n02381460_1439.jpg
# /kaggle/input/horse2zebra/data/train/horses/n02381460_1249.jpg
# /kaggle/input/horse2zebra/data/train/horses/n02381460_411.jpg
# /kaggle/input/horse2zebra/data/train/horses/n02381460_5601.jpg
# /kaggle/input/horse2zebra/data/train/horses/n02381460_1147.jpg
# /kaggle/input/horse2zebra/data/train/horses/n02381460_3857.jpg
# /kaggle/input/horse2zebra/data/train/horses/n02381460_4086.jpg
# /kaggle/input/horse2zebra/data/train/horses/n02381460_4817.jpg
# /kaggle/input/horse2zebra/data/train/horses/n02381460_1501.jpg
# /kaggle/input/horse2zebra/data/train/horses/n02381460_834.jpg
# /kaggle/input/horse2zebra/data/train/horses/n02381460_3601.jpg
# /kaggle/input/horse2zebra/data/train/horses/n02381460_967.jpg
# /kaggle/input/horse2zebra/data/train/horses/n02381460_4781.jpg
# /kaggle/input/horse2zebra/data/train/horses/n02381460_4566.jpg
# /kaggle/input/horse2zebra/data/train/horses/n02381460_2139.jpg
# /kaggle/input/horse2zebra/data/train/horses/n02381460_3108.jpg
# ...
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_9918.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_3177.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_1086.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_936.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_7721.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_9626.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_1189.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_626.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_2749.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_3348.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_6818.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_745.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_3257.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_5781.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_7949.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_3294.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_6503.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_2341.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_9149.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_10427.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_11181.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_2636.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_712.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_6942.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_5236.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_3249.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_2408.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_2407.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_1145.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_5638.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_2.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_10257.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_2691.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_3582.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_764.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_3513.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_404.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_3001.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_2049.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_2017.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_7911.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_2647.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_353.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_566.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_8447.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_851.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_10132.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_6216.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_6962.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_427.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_2416.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_35.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_4058.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_234.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_3202.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_3092.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_713.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_2036.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_6236.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_7563.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_4692.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_3069.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_308.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_3749.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_9336.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_8937.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_2133.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_957.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_6121.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_925.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_2741.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_639.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_6834.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_644.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_3211.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_4922.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_638.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_3135.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_6918.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_1183.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_9822.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_3054.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_251.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_5679.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_283.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_2967.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_1952.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_3436.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_6993.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_9844.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_3785.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_2356.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_538.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_10738.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_633.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_7847.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_2596.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_9193.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_1113.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_4144.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_4329.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_584.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_5633.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_2651.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_2743.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_6991.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_3031.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_999.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_3158.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_635.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_3084.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_3209.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_1038.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_1531.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_839.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_1067.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_2367.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_7258.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_10825.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_787.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_9331.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_2281.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_9273.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_3805.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_6081.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_10209.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_717.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_614.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_4889.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_3038.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_2642.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_10336.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_3105.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_41.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_3536.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_7589.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_1725.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_9487.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_1404.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_2612.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_1026.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_9135.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_2593.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_4879.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_8028.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_796.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_1104.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_3518.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_686.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_2486.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_2511.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_155.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_3443.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_3339.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_1355.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_608.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_7074.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_2771.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_1523.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_2879.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_2201.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_7812.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_2457.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_3264.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_5216.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_1131.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_2464.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_1288.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_2559.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_857.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_9427.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_721.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_718.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_602.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_4448.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_1056.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_7567.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_5695.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_3333.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_9151.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_274.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_1451.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_3248.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_171.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_3018.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_734.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_2506.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_5115.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_3253.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_5356.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_2228.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_2609.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_377.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_8201.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_682.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_2776.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_3221.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_36.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_421.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_2311.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_2886.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_7503.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_3917.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_3296.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_26.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_63.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_487.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_2824.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_221.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_8061.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_10497.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_7919.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_1465.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_2478.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_847.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_3091.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_966.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_108.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_6631.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_10966.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_10339.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_986.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_7407.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_77.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_2197.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_6385.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_4106.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_773.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_6467.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_9417.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_886.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_8857.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_543.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_332.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_1105.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_2949.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_2485.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_3779.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_1743.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_4351.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_2466.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_3174.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_9698.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_3087.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_10175.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_226.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_10576.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_10432.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_121.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_1159.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_33.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_7886.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_5209.jpg
# /kaggle/input/horse2zebra/data/train/zebras/n02391049_9421.jpg

# %%
# !pip install torchmetrics[image]
# !pip install torch-fidelity
# Out:
# Requirement already satisfied: torchmetrics[image] in /opt/conda/lib/python3.10/site-packages (1.3.0.post0)
# Requirement already satisfied: numpy>1.20.0 in /opt/conda/lib/python3.10/site-packages (from torchmetrics[image]) (1.24.4)
# Requirement already satisfied: packaging>17.1 in /opt/conda/lib/python3.10/site-packages (from torchmetrics[image]) (21.3)
# Requirement already satisfied: torch>=1.10.0 in /opt/conda/lib/python3.10/site-packages (from torchmetrics[image]) (2.1.2)
# Requirement already satisfied: lightning-utilities>=0.8.0 in /opt/conda/lib/python3.10/site-packages (from torchmetrics[image]) (0.10.1)
# Requirement already satisfied: torchvision>=0.8 in /opt/conda/lib/python3.10/site-packages (from torchmetrics[image]) (0.16.2)
# Requirement already satisfied: scipy>1.0.0 in /opt/conda/lib/python3.10/site-packages (from torchmetrics[image]) (1.11.4)
# Requirement already satisfied: torch-fidelity<=0.4.0 in /opt/conda/lib/python3.10/site-packages (from torchmetrics[image]) (0.3.0)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from lightning-utilities>=0.8.0->torchmetrics[image]) (69.0.3)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from lightning-utilities>=0.8.0->torchmetrics[image]) (4.9.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>17.1->torchmetrics[image]) (3.1.1)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=1.10.0->torchmetrics[image]) (3.13.1)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.10.0->torchmetrics[image]) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.10.0->torchmetrics[image]) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.10.0->torchmetrics[image]) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch>=1.10.0->torchmetrics[image]) (2023.12.2)
# Requirement already satisfied: Pillow in /opt/conda/lib/python3.10/site-packages (from torch-fidelity<=0.4.0->torchmetrics[image]) (9.5.0)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from torch-fidelity<=0.4.0->torchmetrics[image]) (4.66.1)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from torchvision>=0.8->torchmetrics[image]) (2.31.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.10.0->torchmetrics[image]) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision>=0.8->torchmetrics[image]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision>=0.8->torchmetrics[image]) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision>=0.8->torchmetrics[image]) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision>=0.8->torchmetrics[image]) (2023.11.17)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.10.0->torchmetrics[image]) (1.3.0)

# %% [markdown]
# # imports

# %%
import torch
import albumentations as alb
from albumentations.pytorch import ToTensorV2
import torch.nn as nn
import pandas as pd
from PIL import Image
import os
from torch.utils.data import Dataset
import numpy as np
import sys
from torch.utils.data import DataLoader
import torch.optim as optim
from tqdm import tqdm
from torchvision.utils import save_image
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data.sampler import SubsetRandomSampler
from torchvision import datasets, transforms as tf
from torchvision.models import inception_v3
import albumentations as alb

# %% [markdown]
# # DATA SET

# %%
import os, sys
from torch.utils.data import Dataset
import numpy as np
from PIL import Image



# HorseZebra
class HorseZebraDataset(Dataset):
    def __init__(self, root_y, root_x, transform=None):
        self.root_y = root_y
        self.root_x = root_x
        self.transform = transform

        self.y_images = os.listdir(root_y)
        self.x_images = os.listdir(root_x)
        self.length_dataset = max(len(self.y_images), len(self.x_images)) # 1000, 1500
        self.y_len = len(self.y_images)
        self.x_len = len(self.x_images)

    def __len__(self):
        return self.length_dataset

    def __getitem__(self, index):
        y_img = self.y_images[index % self.y_len]
        x_img = self.x_images[index % self.x_len]

        zebra_path = os.path.join(self.root_y, y_img)
        horse_path = os.path.join(self.root_x, x_img)

        y_img = np.array(Image.open(zebra_path).convert("RGB"))
        x_img = np.array(Image.open(horse_path).convert("RGB"))

        if self.transform:
            augmentations = self.transform(image=y_img, image0=x_img)
            y_img = augmentations["image"]
            x_img = augmentations["image0"]

        return y_img, x_img

# %% [markdown]
# # UTILS

# %%
import torch, os
import numpy as np


def save_checkpoint(model, optimizer, filename="my_checkpoint.pth.tar"):
    print("=> Saving checkpoint")
    checkpoint = {
        "state_dict": model.state_dict(),
        "optimizer": optimizer.state_dict(),
    }
    torch.save(checkpoint, filename)


def load_checkpoint(checkpoint_file, model, optimizer, lr):
    print("=> Loading checkpoint")
    checkpoint = torch.load(checkpoint_file, map_location=DEVICE)
    model.load_state_dict(checkpoint["state_dict"])
    optimizer.load_state_dict(checkpoint["optimizer"])

    # If we don't do this then it will just have learning rate of old checkpoint
    # and it will lead to many hours of debugging \:
    for param_group in optimizer.param_groups:
        param_group["lr"] = lr


def seed_everything(seed=33):
    os.environ["PYTHONHASHSEED"] = str(seed)
    np.random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

# %% [markdown]
# # MODELS

# %%
import torch
import torch.nn as nn
import numpy as np

# For UNET
class DoubleConv(nn. Module):
    def __init__(self, in_channels, out_channels):
        super (DoubleConv, self).__init__()
        self.conv1 = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, 3, 1, 1, bias=False),
            nn.BatchNorm2d (out_channels),
            nn.ReLU(inplace=True),
        )
        self.conv2 = nn.Sequential(
            nn.Conv2d(out_channels, out_channels, 3, 1, 1, bias=False),
            nn.BatchNorm2d (out_channels),
            nn.ReLU(inplace=True),
        )


    def forward (self, x):
        """Residual CONV"""
        x = self.conv1(x)
        return  x + self.conv2(x)


class UNET(nn.Module):
    """
    UNET Module
    """
    def __init__(self, in_channels=3, out_channels=3, features=[64, 128, 256, 512]):
        super (UNET, self).__init__()
        self.upsample_steps = nn.ModuleList()
        self.downsample_steps = nn.ModuleList()
        self.pool = nn. MaxPool2d (kernel_size=2, stride=2)

        # DownsamplingBlock of UNET
        for feature in features:
            self.downsample_steps.append (DoubleConv(in_channels, feature))
            in_channels = feature

        # ##
        self.bottleneck = DoubleConv(features[-1], features [-1]*2)

        # UpsamplingBlock of UNET
        for feature in reversed(features):
            self.upsample_steps.append(nn.ConvTranspose2d(feature*2, feature, kernel_size=2, stride=2))

            self.upsample_steps.append(DoubleConv(feature*2, feature))

        self.final_conv = nn.Conv2d(features[0], out_channels, kernel_size=1)

    def forward(self, x):
        skip_connections = []

        # downsample
        for downsample in self.downsample_steps:
            x = downsample(x)
            skip_connections.append(x)
            x = self.pool(x)

        # bottleneck - before upsample
        x = self.bottleneck(x)
        skip_connections = skip_connections[::-1]

        # upsample
        for index in range(0, len(self.upsample_steps), 2):
            x = self.upsample_steps[index](x)
            skip_connection = skip_connections[index//2]
            concat_skip = torch.cat((skip_connection, x), dim=1)
            x = self.upsample_steps[index+1](concat_skip)
        return self.final_conv(x)




# ViT
def patchify(images, n_patches):
    n, c, h, w = images.shape

    assert h == w, "Patchify method is implemented for square images only"

    patches = torch.zeros(n, n_patches ** 2, h * w * c // n_patches ** 2)
    patch_size = h // n_patches

    for idx, image in enumerate(images):
        for i in range(n_patches):
            for j in range(n_patches):
                patch = image[:, i * patch_size: (i + 1) * patch_size, j * patch_size: (j + 1) * patch_size]
                patches[idx, i * n_patches + j] = patch.flatten()
    return patches


def get_positional_embeddings(sequence_length, d):
    result = torch.ones(sequence_length, d)
    for i in range(sequence_length):
        for j in range(d):
            result[i][j] = np.sin(i / (10000 ** (j / d))) if j % 2 == 0 else np.cos(i / (10000 ** ((j - 1) / d)))
    return result


class MSA(nn.Module):
    def __init__(self, d, n_heads=2):
        super(MSA, self).__init__()
        self.d = d
        self.n_heads = n_heads

        assert d % n_heads == 0, f"Can't divide dimension {d} into {n_heads} heads"

        d_head = int(d / n_heads)
        self.q_mappings = nn.ModuleList([nn.Linear(d_head, d_head) for _ in range(self.n_heads)])
        self.k_mappings = nn.ModuleList([nn.Linear(d_head, d_head) for _ in range(self.n_heads)])
        self.v_mappings = nn.ModuleList([nn.Linear(d_head, d_head) for _ in range(self.n_heads)])
        self.d_head = d_head
        self.softmax = nn.Softmax(dim=-1)

    def forward(self, sequences):
        # Sequences has shape (N, seq_length, token_dim)
        # We go into shape    (N, seq_length, n_heads, token_dim / n_heads)
        # And come back to    (N, seq_length, item_dim)  (through concatenation)
        result = []
        for sequence in sequences:
            seq_result = []
            for head in range(self.n_heads):
                q_mapping = self.q_mappings[head]
                k_mapping = self.k_mappings[head]
                v_mapping = self.v_mappings[head]

                seq = sequence[:, head * self.d_head: (head + 1) * self.d_head]
                q, k, v = q_mapping(seq), k_mapping(seq), v_mapping(seq)

                attention = self.softmax(q @ k.T / (self.d_head ** 0.5))
                seq_result.append(attention @ v)
            result.append(torch.hstack(seq_result))
        return torch.cat([torch.unsqueeze(r, dim=0) for r in result])


class ViTBlock(nn.Module):
    def __init__(self, hidden_d, n_heads, mlp_ratio=4):
        super(ViTBlock, self).__init__()
        self.hidden_d = hidden_d
        self.n_heads = n_heads

        self.norm1 = nn.LayerNorm(hidden_d)
        self.mhsa = MSA(hidden_d, n_heads)
        self.norm2 = nn.LayerNorm(hidden_d)
        self.mlp = nn.Sequential(
            nn.Linear(hidden_d, mlp_ratio * hidden_d),
            nn.GELU(),
            nn.Linear(mlp_ratio * hidden_d, hidden_d)
        )

    def forward(self, x):
        out = x + self.mhsa(self.norm1(x))
        out = out + self.mlp(self.norm2(out))
        return out


class ViT(nn.Module):
    def __init__(self, chw, n_patches=7, n_blocks=2, hidden_d=8, n_heads=2, out_d=1):
        # Super constructor
        super(ViT, self).__init__()

        # Attributes
        self.chw = chw # ( C , H , W )
        self.n_patches = n_patches
        self.n_blocks = n_blocks
        self.n_heads = n_heads
        self.hidden_d = hidden_d

        # Input and patches sizes
        assert chw[1] % n_patches == 0, "Input shape not entirely divisible by number of patches"
        assert chw[2] % n_patches == 0, "Input shape not entirely divisible by number of patches"
        self.patch_size = (chw[1] / n_patches, chw[2] / n_patches)

        # 1) Linear mapper
        self.input_d = int(chw[0] * self.patch_size[0] * self.patch_size[1])
        self.linear_mapper = nn.Linear(self.input_d, self.hidden_d)

        # 2) Learnable classification token
        self.class_token = nn.Parameter(torch.rand(1, self.hidden_d))

        # 3) Positional embedding
        self.register_buffer('positional_embeddings', get_positional_embeddings(n_patches ** 2 + 1, hidden_d), persistent=False)

        # 4) Transformer encoder blocks
        self.blocks = nn.ModuleList([ViTBlock(hidden_d, n_heads) for _ in range(n_blocks)])

        # 5) Classification FCN
        self.mlp = nn.Sequential(
            nn.Linear(self.hidden_d, out_d),
            nn.Sigmoid()
        )

    def forward(self, images):
        # Dividing images into patches
        n, c, h, w = images.shape
        patches = patchify(images, self.n_patches).to(self.positional_embeddings.device)

        # Running linear layer tokenization
        # Map the vector corresponding to each patch to the hidden size dimension
        tokens = self.linear_mapper(patches)

        # Adding classification token to the tokens
        tokens = torch.cat((self.class_token.expand(n, 1, -1), tokens), dim=1)

        # Adding positional embedding
        out = tokens + self.positional_embeddings.repeat(n, 1, 1)

        # Transformer Blocks
        for block in self.blocks:
            out = block(out)
        return out
        # Getting the classification token only
        out = out[:, 0]

        return self.mlp(out)


# LSB Steganography
class StegoEmbeddingLayer(nn.Module):
    def __init__(self):
        super(StegoEmbeddingLayer, self).__init__()

    def forward(self, image, text):
        """
        Embeds text into the RGB image using LSB steganography.

        Parameters:
        - image (torch.Tensor): RGB image tensor of shape (batch_size, 3, height, width).
        - text (str): The text to be embedded into the image.

        Returns:
        - torch.Tensor: Embedded image tensor.
        """
        batch_size, channels, height, width = image.size()

        # Text => binary
        binary_text = ''.join(bin(ord(char)) for char in text)
        binary_text += '1111111111111110'  # delimiter

        binary_index = 0

        # Embed the text into LSB
        for i in range(batch_size):
            for j in range(channels):
                for k in range(height):
                    for l in range(width):
                        pixel_value = image[i, j, k, l]
                        binary_pixel_value = format(pixel_value.item(), '08b')

                        # Modify the LSB to encode the text
                        binary_pixel_value = binary_pixel_value[:-1] + binary_text[binary_index]
                        binary_index = (binary_index + 1) % len(binary_text)

                        # Convert the binary pixel back to decimal
                        embedded_pixel_value = int(binary_pixel_value[:-1], 2)

                        image[i, j, k, l] = embedded_pixel_value

        return image

# Tests
def test_Disc():
    x = torch.randn((5, 3, 256, 256))
    # model = Discriminator(in_channels=3)
    model = ViT((3, 256, 256), n_patches=16, n_blocks=2, hidden_d=8, n_heads=2, out_d=1)
    preds = model(x)
    print(preds.shape)


def test_Gen():
    img_channels = 3
    img_size = 256
    x = torch.randn((2, img_channels, img_size, img_size))
    gen = UNET(img_channels)
    print(gen(x).shape)

# %% [markdown]
# # EVALUATIONS

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchmetrics.image.inception import InceptionScore
from torchmetrics.image.fid import FrechetInceptionDistance
from torchmetrics.image import PeakSignalNoiseRatio
from torch.utils.data import DataLoader


def evaluate(real_images, fake_images):
    """
    Calculates the FID of a batch of real and fake images.

    Args:
        real_images: A PyTorch tensor of real images.
        fake_images: A PyTorch tensor of fake images.

    Returns:
        Tuple Scores.
    """

    # Calculate the mean squared error between the real and fake images.
    real_images = real_images.type(torch.FloatTensor)
    fake_images = fake_images.type(torch.FloatTensor)
    mse_loss = nn.MSELoss()(real_images, fake_images)

    # Example plotting a single value

    metric = PeakSignalNoiseRatio()
    psnr = metric(fake_images, real_images)
    # fig_, ax_ = metric.plot(psnr)

    # Computes the inception score of the generated images.
    real_images = real_images.type(torch.uint8)
    fake_images = fake_images.type(torch.uint8)
    inception = InceptionScore()
    inception.update(real_images)
    inc_score = inception.compute()
    inception.reset()

    # Calculates the FID of a batch of real and fake images.
    fid = FrechetInceptionDistance(feature=64)
    fid.update(real_images, real=True)
    fid.update(fake_images, real=False)
    fid_score = fid.compute()


    return dict(MSELoss=mse_loss.item(), PeakSignalNoiseRatio=psnr.item(), InceptionScore_mean=inc_score[0].item(), InceptionScore_std=inc_score[1].item(), FrechetInceptionDistance=fid_score.item())

# %% [markdown]
# # Configurations

# %%
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
TRAIN_DIR = "/kaggle/input/horse2zebra/data/train"
VAL_DIR = "/kaggle/input/horse2zebra/data/test"
BATCH_SIZE = 8
LEARNING_RATE = 1e-5
LAMBDA_IDENTITY = 0.0
LAMBDA_CYCLE = 10
NUM_WORKERS = 2
NUM_EPOCHS = 1
LOAD_MODEL = False
SAVE_MODEL = True
CHECKPOINT_GEN_X= "genX.pth.tar"
CHECKPOINT_GEN_Y = "genY.pth.tar"
CHECKPOINT_DISC_X = "discX.pth.tar"
CHECKPOINT_DISC_Y = "discY.pth.tar"
SAVE_PATH = '.'

# %%
transforms_alb = alb.Compose(
    [
        alb.Resize(width=64, height=64),
        ToTensorV2(),
    ],
    additional_targets={"image0": "image"},
)

# %% [markdown]
# # Train

# %%
def train_fn(disc_X, disc_Y, gen_Y, gen_X, loader, opt_disc, opt_gen, l1, mse, d_scaler, g_scaler, embed, steganolysis):
    X_reals = 0
    X_fakes = 0
    loop = tqdm(loader, leave=True)

    for idx, (Y, X) in enumerate(loop):
        Y = Y.to(DEVICE).type(torch.float16)
        X = X.to(DEVICE).type(torch.float16)

        # Train Discriminators X and Y
        with torch.cuda.amp.autocast():
            fake_X = gen_X(Y)

            D_X_real = disc_X(X)
            D_X_fake = disc_X(fake_X.detach())
            X_reals += D_X_real.mean().item()
            X_fakes += D_X_fake.mean().item()
            D_X_real_loss = mse(D_X_real, torch.ones_like(D_X_real))
            D_X_fake_loss = mse(D_X_fake, torch.zeros_like(D_X_fake))
            D_X_loss = D_X_real_loss + D_X_fake_loss

            # steganolysis
            embed_X = embed(fake_X.detach().type(torch.uint8), text='SECRET')
            STEGO_LOSS_X = mse(steganolysis(fake_X.detach().type(torch.uint8)), steganolysis(embed_X.detach().type(torch.uint8)))

            fake_Y = gen_Y(X)

            D_Y_real = disc_Y(Y)
            D_Y_fake = disc_Y(fake_Y.detach())
            D_Y_real_loss = mse(D_Y_real, torch.ones_like(D_Y_real))
            D_Y_fake_loss = mse(D_Y_fake, torch.zeros_like(D_Y_fake))
            D_Y_loss = D_Y_real_loss + D_Y_fake_loss

            # steganolysis
            embed_Y = embed(fake_Y.detach().type(torch.uint8), text='SECRET')
            STEGO_LOSS_Y = mse(steganolysis(fake_Y.detach().type(torch.uint8)), steganolysis(embed_Y.detach().type(torch.uint8)))




            # put it togethor
            D_loss = (D_X_loss + D_Y_loss + STEGO_LOSS_X + STEGO_LOSS_Y) / 4


        opt_disc.zero_grad()
        d_scaler.scale(D_loss).backward()
        d_scaler.step(opt_disc)
        d_scaler.update()



        # Train Generators H and Z
        with torch.cuda.amp.autocast():
            # adversarial loss for both generators
            D_X_fake = disc_X(fake_X)
            D_Y_fake = disc_Y(fake_Y)
            loss_G_X = mse(D_X_fake, torch.ones_like(D_X_fake))
            loss_G_Y = mse(D_Y_fake, torch.ones_like(D_Y_fake))

            # cycle loss
            cycle_X = gen_Y(fake_X)
            cycle_Y = gen_X(fake_Y)
            cycle_Y_loss = l1(X, cycle_Y)
            cycle_X_loss = l1(Y, cycle_X)

            # identity loss (remove these for efficiency if you set lambda_identity=0)
            identity_Y = gen_Y(Y)
            identity_X = gen_X(X)
            identity_Y_loss = l1(Y, identity_Y)
            identity_X_loss = l1(X, identity_X)

            # add all togethor
            G_loss = (
                loss_G_Y
                + loss_G_X
                + cycle_Y_loss * LAMBDA_CYCLE
                + cycle_X_loss * LAMBDA_CYCLE
                + identity_X_loss * LAMBDA_IDENTITY
                + identity_Y_loss * LAMBDA_IDENTITY
            )

        opt_gen.zero_grad()
        g_scaler.scale(G_loss).backward()
        g_scaler.step(opt_gen)
        g_scaler.update()



        if idx % 5 == 0:
            save_image(X * 0.5 + 0.5, f"X_ORG_{idx}.png")
            save_image(Y * 0.5 + 0.5, f"Y_ORG_{idx}.png")
            save_image(fake_X * 0.5 + 0.5, f"X_{idx}.png")
            save_image(fake_Y * 0.5 + 0.5, f"Y_{idx}.png")


        loop.set_postfix(
            X_real=X_reals / (idx + 1),X_fake=X_fakes / (idx + 1),
            Generator_Loss=G_loss.item(), Discriminator_Loss=D_loss.item()
            )

    return G_loss.item(), D_loss.item()

# %%
def train():
    global metrics
    # disc_X = Discriminator(in_channels=3).to(DEVICE)
    disc_X = ViT((3, 64, 64), n_patches=16, n_blocks=2, hidden_d=8, n_heads=2, out_d=1)
    # disc_Y = Discriminator(in_channels=3).to(DEVICE)
    disc_Y = ViT((3, 64, 64), n_patches=16, n_blocks=2, hidden_d=8, n_heads=2, out_d=1)
    gen_Y = UNET(in_channels=3).to(DEVICE)
    gen_X = UNET(in_channels=3).to(DEVICE)
    steganolysis = ViT((3, 64, 64), n_patches=16, n_blocks=2, hidden_d=8, n_heads=2, out_d=1)
    embed = StegoEmbeddingLayer()

    # optimizers
    opt_disc = optim.Adam(
        list(disc_X.parameters()) + list(disc_Y.parameters()),
        lr=LEARNING_RATE,
        betas=(0.5, 0.999),
    )

    opt_gen = optim.Adam(
        list(gen_Y.parameters()) + list(gen_X.parameters()),
        lr=LEARNING_RATE,
        betas=(0.5, 0.999),
    )

    L1 = nn.L1Loss()
    mse = nn.MSELoss()

    if LOAD_MODEL:
        load_checkpoint(
            CHECKPOINT_GEN_X,
            gen_X,
            opt_gen,
            LEARNING_RATE,
        )
        load_checkpoint(
            CHECKPOINT_GEN_Y,
            gen_Y,
            opt_gen,
            LEARNING_RATE,
        )
        load_checkpoint(
            CHECKPOINT_DISC_X,
            disc_X,
            opt_disc,
            LEARNING_RATE,
        )
        load_checkpoint(
            CHECKPOINT_DISC_Y,
            disc_Y,
            opt_disc,
            LEARNING_RATE,
        )

    dataset = HorseZebraDataset(
        root_x=TRAIN_DIR + "/horses",
        root_y=TRAIN_DIR + "/zebras",
        transform=transforms_alb,
    )
    val_dataset = HorseZebraDataset(
        root_x=VAL_DIR + "/horses",
        root_y=VAL_DIR + "/zebras",
        transform=transforms_alb,
    )
    val_loader = DataLoader(
        val_dataset,
        batch_size=2,
        shuffle=False,
        pin_memory=True,
    )
    loader = DataLoader(
        dataset,
        batch_size=BATCH_SIZE,
        shuffle=True,
        num_workers=NUM_WORKERS,
        pin_memory=True,
    )
    g_scaler = torch.cuda.amp.GradScaler(enabled=False)
    d_scaler = torch.cuda.amp.GradScaler(enabled=False)


    for epoch in range(NUM_EPOCHS):
        g, d = train_fn(disc_X, disc_Y, gen_Y, gen_X, loader, opt_disc, opt_gen, L1, mse, d_scaler, g_scaler, embed, steganolysis)

        # Evaluate
        scores = pd.DataFrame(columns=['FrechetInceptionDistance', 'InceptionScore_mean', 'InceptionScore_std', 'MSELoss', 'PeakSignalNoiseRatio'])
        for idx, (Y, X) in enumerate(val_loader):
            Y = Y.to(DEVICE).type(torch.float16)
            X = X.to(DEVICE).type(torch.float16)

            # Train Discriminators X and Y
            with torch.cuda.amp.autocast():
                Y_fake = gen_Y(X)
                sc = evaluate(Y, Y_fake)
                scores.loc[idx] = sc

        scores = scores.mean().to_dict()
        scores['Discriminator_loss'] = g
        scores['Generator_loss'] = d
        metrics.loc[epoch] = scores

        if SAVE_MODEL and (epoch%1 == 0):
            # save_checkpoint(gen_X, opt_gen, filename=CHECKPOINT_GEN_X)
            # save_checkpoint(gen_Y, opt_gen, filename=CHECKPOINT_GEN_Y)
            # save_checkpoint(disc_X, opt_disc,
            #                 filename=CHECKPOINT_DISC_X)
            # save_checkpoint(disc_Y, opt_disc,
            #                 filename=CHECKPOINT_DISC_Y)


            torch.save(gen_X.state_dict(), SAVE_PATH+'/GenX.pt')
            torch.save(gen_Y.state_dict(), SAVE_PATH+'/GenY.pt')
            torch.save(disc_X.state_dict(), SAVE_PATH+'/DiscX.pt')
            torch.save(disc_Y.state_dict(), SAVE_PATH+'/DiscY.pt')

# %%
import warnings
warnings.filterwarnings(action='ignore')
metrics = pd.DataFrame(columns=['Discriminator_loss', 'Generator_loss','FrechetInceptionDistance', 'InceptionScore_mean', 'InceptionScore_std', 'MSELoss', 'PeakSignalNoiseRatio'])
seed_everything()
train()
# Out:
#  20%|██        | 34/167 [06:14<24:24, 11.01s/it, Discriminator_Loss=2.45e+3, Generator_Loss=2.33e+3, X_fake=0.411, X_real=67.3]
